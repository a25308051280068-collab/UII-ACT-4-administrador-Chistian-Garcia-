# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280068-collab/UII-ACT-4-administrador-Chistian-Garcia-/blob/main/UII_Act_4_administrador_Christian_Garcia_0068.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Christian Garcia NL = 21 Fecha = 13/05/2026
# ### Diccionario_administrador[].
# # Caso 21

# %%
# 1. Inicialización del diccionario vacío
# Aquí es donde se guardará toda la información que ingreses
diccionario_administrador = {}

def agregar_administrador():
    print("\n--- Agregar Nuevo Administrador ---")
    # Los inputs capturan los datos para el VALUE
    empresa = input("Empresa (Esta será la CLAVE/KEY): ")
    depto = input("Departamento: ")
    presupuesto = input("Presupuesto asignado: ")
    personal = input("Personal a cargo: ")
    metas = input("Metas trimestrales: ")
    erp = input("Software ERP: ")

    # Se crea el registro vinculando la KEY (empresa) con su VALUE (diccionario interno)
    diccionario_administrador[empresa] = {
        "departamento": depto,
        "presupuesto": presupuesto,
        "personal": personal,
        "metas": metas,
        "erp": erp
    }
    print(f"\n¡Registro de {empresa} agregado con éxito!")
    listar_administrador()

def listar_administrador():
    print("\n--- Lista de Administradores (CBTIS 128) ---")
    if not diccionario_administrador:
        print("El diccionario está vacío actualmente. Agregue datos en la opción 1.")
    else:
        # Encabezados de la tabla
        print(f"{'Empresa (KEY)':<15} | {'Depto':<15} | {'Presupuesto':<12} | {'Personal':<10} | {'Metas':<15} | {'ERP':<10}")
        print("-" * 95)
        # Recorrido obligatorio usando for clave, valor (key, value)
        for empresa, datos in diccionario_administrador.items():
            print(f"{empresa:<15} | {datos['departamento']:<15} | {datos['presupuesto']:<12} | {datos['personal']:<10} | {datos['metas']:<15} | {datos['erp']:<10}")

def buscar_administrador():
    print("\n--- Buscar Administrador ---")
    nombre = input("Ingrese el nombre de la empresa (KEY) a buscar: ")
    if nombre in diccionario_administrador:
        # Recuperamos el VALUE asociado a esa KEY
        valor = diccionario_administrador[nombre]
        print(f"\n[RESULTADO] Empresa: {nombre}")
        print(f"Datos encontrados: {valor}")
    else:
        print("\nError: Esa clave no existe en el sistema.")
    listar_administrador()

def borrar_administrador():
    print("\n--- Borrar Administrador ---")
    nombre = input("Ingrese el nombre de la empresa a eliminar: ")
    if nombre in diccionario_administrador:
        # Eliminamos la KEY y automáticamente su VALUE
        del diccionario_administrador[nombre]
        print(f"\nRegistro de {nombre} eliminado correctamente.")
    else:
        print("\nError: No se puede borrar una empresa que no existe.")
    listar_administrador()

def actualizar_administrador():
    print("\n--- Actualizar Administrador ---")
    nombre = input("Ingrese el nombre de la empresa que desea modificar: ")
    if nombre in diccionario_administrador:
        print(f"Modificando datos para: {nombre}")
        # Se sobreescriben los VALUES manteniendo la misma KEY
        depto = input("Nuevo Departamento: ")
        presupuesto = input("Nuevo Presupuesto: ")
        personal = input("Nuevo Personal: ")
        metas = input("Nuevas Metas: ")
        erp = input("Nuevo Software ERP: ")

        diccionario_administrador[nombre] = {
            "departamento": depto,
            "presupuesto": presupuesto,
            "personal": personal,
            "metas": metas,
            "erp": erp
        }
        print("\nDatos actualizados.")
    else:
        print("\nError: Empresa no encontrada.")
    listar_administrador()

# --- Bloque Principal (Menú) ---
while True:
    print("\n================================================")
    print("      SISTEMA DE CONTROL DE ADMINISTRADORES      ")
    print("   CBTIS 128 | Alumno: Christian Garcia Jiemenez ")
    print("================================================")
    print("1. Agregar administrador (KEY:VALUE)")
    print("2. Listar administradores")
    print("3. Buscar administrador")
    print("4. Borrar administrador")
    print("5. Actualizar administrador")
    print("6. Salir")

    opcion = input("\nSeleccione una opción (1-6): ")

    if opcion == "1":
        agregar_administrador()
    elif opcion == "2":
        listar_administrador()
    elif opcion == "3":
        buscar_administrador()
    elif opcion == "4":
        borrar_administrador()
    elif opcion == "5":
        actualizar_administrador()
    elif opcion == "6":
        print("Cerrando programa... ¡Hasta luego!")
        break
    else:
        print("Opción inválida. Por favor, marque un número del 1 al 6.")
        print("Programa realizado por Christian Garcia NL = 21")
# Out:
# ================================================
#       SISTEMA DE CONTROL DE ADMINISTRADORES
#    CBTIS 128 | Alumno: Christian Garcia Jiemenez
# ================================================
# 1. Agregar administrador (KEY:VALUE)
# 2. Listar administradores
# 3. Buscar administrador
# 4. Borrar administrador
# 5. Actualizar administrador
# 6. Salir
#
# Seleccione una opción (1-6): 1
#
# --- Agregar Nuevo Administrador ---
# Empresa (Esta será la CLAVE/KEY): chano
# Departamento: it
# Presupuesto asignado: 454534
# Personal a cargo: 35545454
# Metas trimestrales: 66565656
# Software ERP: intel
#
# ¡Registro de chano agregado con éxito!
#
# --- Lista de Administradores (CBTIS 128) ---
# Empresa (KEY)   | Depto           | Presupuesto  | Personal   | Metas           | ERP
# -----------------------------------------------------------------------------------------------
# chano           | it              | 454534       | 35545454   | 66565656        | intel
#
# ================================================
#       SISTEMA DE CONTROL DE ADMINISTRADORES
#    CBTIS 128 | Alumno: Christian Garcia Jiemenez
# ================================================
# 1. Agregar administrador (KEY:VALUE)
# 2. Listar administradores
# 3. Buscar administrador
# 4. Borrar administrador
# 5. Actualizar administrador
# 6. Salir
#
# Seleccione una opción (1-6): 1
#
# --- Agregar Nuevo Administrador ---
# Empresa (Esta será la CLAVE/KEY): android
# Departamento: ventas
# Presupuesto asignado: 656889
# Personal a cargo: 54
# Metas trimestrales: 54654
# Software ERP: windows
#
# ¡Registro de android agregado con éxito!
#
# --- Lista de Administradores (CBTIS 128) ---
# Empresa (KEY)   | Depto           | Presupuesto  | Personal   | Metas           | ERP
# -----------------------------------------------------------------------------------------------
# chano           | it              | 454534       | 35545454   | 66565656        | intel
# android         | ventas          | 656889       | 54         | 54654           | windows
#
# ================================================
#       SISTEMA DE CONTROL DE ADMINISTRADORES
#    CBTIS 128 | Alumno: Christian Garcia Jiemenez
# ================================================
# 1. Agregar administrador (KEY:VALUE)
# 2. Listar administradores
# 3. Buscar administrador
# 4. Borrar administrador
# 5. Actualizar administrador
# 6. Salir
#
# Seleccione una opción (1-6): 1
#
# --- Agregar Nuevo Administrador ---
# Empresa (Esta será la CLAVE/KEY): chano
# Departamento: compras
# Presupuesto asignado: 545455
# Personal a cargo: 56
# Metas trimestrales: 454554
# Software ERP: apple
#
# ¡Registro de chano agregado con éxito!
#
# --- Lista de Administradores (CBTIS 128) ---
# Empresa (KEY)   | Depto           | Presupuesto  | Personal   | Metas           | ERP
# -----------------------------------------------------------------------------------------------
# chano           | compras         | 545455       | 56         | 454554          | apple
# android         | ventas          | 656889       | 54         | 54654           | windows
#
# ================================================
#       SISTEMA DE CONTROL DE ADMINISTRADORES
#    CBTIS 128 | Alumno: Christian Garcia Jiemenez
# ================================================
# 1. Agregar administrador (KEY:VALUE)
# 2. Listar administradores
# 3. Buscar administrador
# 4. Borrar administrador
# 5. Actualizar administrador
# 6. Salir
#
# Seleccione una opción (1-6): 1
#
# --- Agregar Nuevo Administrador ---
# Empresa (Esta será la CLAVE/KEY): apple
# Departamento: ventas
# Presupuesto asignado: 56564
# Personal a cargo: 89
# Metas trimestrales: 343422
# Software ERP: intel
#
# ¡Registro de apple agregado con éxito!
#
# --- Lista de Administradores (CBTIS 128) ---
# Empresa (KEY)   | Depto           | Presupuesto  | Personal   | Metas           | ERP
# -----------------------------------------------------------------------------------------------
# chano           | compras         | 545455       | 56         | 454554          | apple
# android         | ventas          | 656889       | 54         | 54654           | windows
# apple           | ventas          | 56564        | 89         | 343422          | intel
#
# ================================================
#       SISTEMA DE CONTROL DE ADMINISTRADORES
#    CBTIS 128 | Alumno: Christian Garcia Jiemenez
# ================================================
# 1. Agregar administrador (KEY:VALUE)
# 2. Listar administradores
# 3. Buscar administrador
# 4. Borrar administrador
# 5. Actualizar administrador
# 6. Salir
#
# Seleccione una opción (1-6): 1
#
# --- Agregar Nuevo Administrador ---
# Empresa (Esta será la CLAVE/KEY): tema
# Departamento: biberos
# Presupuesto asignado: 16262
# Personal a cargo: 78
# Metas trimestrales: 66454
# Software ERP: windows2
#
# ¡Registro de tema agregado con éxito!
#
# --- Lista de Administradores (CBTIS 128) ---
# Empresa (KEY)   | Depto           | Presupuesto  | Personal   | Metas           | ERP
# -----------------------------------------------------------------------------------------------
# chano           | compras         | 545455       | 56         | 454554          | apple
# android         | ventas          | 656889       | 54         | 54654           | windows
# apple           | ventas          | 56564        | 89         | 343422          | intel
# tema            | biberos         | 16262        | 78         | 66454           | windows2
#
# ================================================
#       SISTEMA DE CONTROL DE ADMINISTRADORES
#    CBTIS 128 | Alumno: Christian Garcia Jiemenez
# ================================================
# 1. Agregar administrador (KEY:VALUE)
# 2. Listar administradores
# 3. Buscar administrador
# 4. Borrar administrador
# 5. Actualizar administrador
# 6. Salir
#
# Seleccione una opción (1-6): 2
#
# --- Lista de Administradores (CBTIS 128) ---
# Empresa (KEY)   | Depto           | Presupuesto  | Personal   | Metas           | ERP
# -----------------------------------------------------------------------------------------------
# chano           | compras         | 545455       | 56         | 454554          | apple
# android         | ventas          | 656889       | 54         | 54654           | windows
# apple           | ventas          | 56564        | 89         | 343422          | intel
# tema            | biberos         | 16262        | 78         | 66454           | windows2
#
# ================================================
#       SISTEMA DE CONTROL DE ADMINISTRADORES
#    CBTIS 128 | Alumno: Christian Garcia Jiemenez
# ================================================
# 1. Agregar administrador (KEY:VALUE)
# 2. Listar administradores
# 3. Buscar administrador
# 4. Borrar administrador
# 5. Actualizar administrador
# 6. Salir
#
# Seleccione una opción (1-6): 3
#
# --- Buscar Administrador ---
# Ingrese el nombre de la empresa (KEY) a buscar: chano
#
# [RESULTADO] Empresa: chano
# Datos encontrados: {'departamento': 'compras', 'presupuesto': '545455', 'personal': '56', 'metas': '454554', 'erp': 'apple'}
#
# --- Lista de Administradores (CBTIS 128) ---
# Empresa (KEY)   | Depto           | Presupuesto  | Personal   | Metas           | ERP
# -----------------------------------------------------------------------------------------------
# chano           | compras         | 545455       | 56         | 454554          | apple
# android         | ventas          | 656889       | 54         | 54654           | windows
# apple           | ventas          | 56564        | 89         | 343422          | intel
# tema            | biberos         | 16262        | 78         | 66454           | windows2
#
# ================================================
#       SISTEMA DE CONTROL DE ADMINISTRADORES
#    CBTIS 128 | Alumno: Christian Garcia Jiemenez
# ================================================
# 1. Agregar administrador (KEY:VALUE)
# 2. Listar administradores
# 3. Buscar administrador
# 4. Borrar administrador
# 5. Actualizar administrador
# 6. Salir
#
# Seleccione una opción (1-6): 4
#
# --- Borrar Administrador ---
# Ingrese el nombre de la empresa a eliminar: tema
#
# Registro de tema eliminado correctamente.
#
# --- Lista de Administradores (CBTIS 128) ---
# Empresa (KEY)   | Depto           | Presupuesto  | Personal   | Metas           | ERP
# -----------------------------------------------------------------------------------------------
# chano           | compras         | 545455       | 56         | 454554          | apple
# android         | ventas          | 656889       | 54         | 54654           | windows
# apple           | ventas          | 56564        | 89         | 343422          | intel
#
# ================================================
#       SISTEMA DE CONTROL DE ADMINISTRADORES
#    CBTIS 128 | Alumno: Christian Garcia Jiemenez
# ================================================
# 1. Agregar administrador (KEY:VALUE)
# 2. Listar administradores
# 3. Buscar administrador
# 4. Borrar administrador
# 5. Actualizar administrador
# 6. Salir
#
# Seleccione una opción (1-6): 5
#
# --- Actualizar Administrador ---
# Ingrese el nombre de la empresa que desea modificar: apple
# Modificando datos para: apple
# Nuevo Departamento: compras
# Nuevo Presupuesto: 4545
# Nuevo Personal: 12
# Nuevas Metas: 12000
# Nuevo Software ERP: windows
#
# Datos actualizados.
#
# --- Lista de Administradores (CBTIS 128) ---
# Empresa (KEY)   | Depto           | Presupuesto  | Personal   | Metas           | ERP
# -----------------------------------------------------------------------------------------------
# chano           | compras         | 545455       | 56         | 454554          | apple
# android         | ventas          | 656889       | 54         | 54654           | windows
# apple           | compras         | 4545         | 12         | 12000           | windows
#
# ================================================
#       SISTEMA DE CONTROL DE ADMINISTRADORES
#    CBTIS 128 | Alumno: Christian Garcia Jiemenez
# ================================================
# 1. Agregar administrador (KEY:VALUE)
# 2. Listar administradores
# 3. Buscar administrador
# 4. Borrar administrador
# 5. Actualizar administrador
# 6. Salir
#
# Seleccione una opción (1-6): 6
# Cerrando programa... ¡Hasta luego!

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/a25308051280068-collab/UII-ACT-4-administrador-Chistian-Garcia-/refs/heads/main/3281a1e6-4f23-4d7e-a230-d63e5c7db2fd.jpg)
